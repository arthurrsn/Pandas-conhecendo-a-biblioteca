# %% [markdown]
# <a href="https://colab.research.google.com/github/arthurrsn/Pandas-conhecendo-a-biblioteca/blob/main/notebook/Colocando_na_pratica_pandas_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Colocando em prática!**
#
# ![AnyConv.com__coder-illustration-1024x683.png](data:image/png;base64,...)
#
# O objetivo é pegar os conhecimentos obtidos e aplicados no notebook [Pandas_conhecendo_a_biblioteca.ipynb](https://github.com/arthurrsn/Pandas-conhecendo-a-biblioteca/blob/main/notebook/Pandas_conhecendo_a_biblioteca.ipynb) e colocar em prática. Para isso uitlizaremos o arquivo [alunos.csv](https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv) disponibilizado para fazer análises e aprender mais sobre o pandas.
#
# ---

# %%
import pandas as pd

# armazenando os dados do arquivo alunos.csv na var df e exibindo
URL = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'
df = pd.read_csv(URL)
df
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# Após fazermos essa primeira exibição precisamos traçar os objetivos.
#
# 1. Visualize as primeiras 7 linhas do DataFrame e as 5 últimas.
# 2. Confira a quantidade de linhas e colunas desse DataFrame.
# 3. Explore as colunas do DataFrame e analise os tipos dos dados presentes em cada coluna.
#
# Extra: Calcule algumas estatísticas descritivas básicas dos dados do DataFrame (média, desvio padrão, etc). Dica: pesquise pelo método describe.
#
# ---
#
# 1 _> Para visualizarmos as 7 primeiras e 5 últimas linhas vamos utilizar as funções .head() e .tail().

# %%
df.head(7) # visualizando as 7 primeiras linhas
# Out:
#     Nome  Idade  Notas  Aprovado
# 0    Ary     20    7.5      True
# 1    Ana     18    NaN     False
# 2  Cátia     27    2.5     False
# 3  Denis     18    5.0     False
# 4   Beto     21   10.0      True
# 5  Bruna     23    NaN     False
# 6   Dara     21    7.0      True

# %%
df.tail(5) # visualizando as 5 últimas linhas
# Out:
#       Nome  Idade  Notas  Aprovado
# 13   Mirla     25    9.0      True
# 14   Paulo     37    NaN     False
# 15  Mylena     29    7.0      True
# 16   Lucas     33    NaN     False
# 17   Nadia     34    8.0      True

# %% [markdown]
# Perfeito. Após isso conseguimos executar o próximo passo:
#
# 2 _> Para conferirmos a quantidade de linhas e colunas utilizaremos a função .shape

# %%
df.shape # exibe a quantidade de linhas e colunas presente no DataFrame.
# Out:
# (18, 4)

# %% [markdown]
# Ótimo! Temos 18 linhas e 4 colunas.
#
# 3 _> Sabendo as dimensões do Df, que tal verificarmos os tipos de dados presentes nele utilizando a função .info()

# %%
df.info() # verificar as informações disponíveis, como: valores NaNs, tipos de dados e etc.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nome      18 non-null     object
#  1   Idade     18 non-null     int64
#  2   Notas     12 non-null     float64
#  3   Aprovado  18 non-null     bool
# dtypes: bool(1), float64(1), int64(1), object(1)
# memory usage: 578.0+ bytes

# %% [markdown]
# Interessante. Temos colunas com tipos diferentes umas das outras.
#
# Na coluna de notas temos 6 valores nulos. Iremos relevar por enquanto levando em conta o prograsso do curso.

# %%
df.describe() # pegando uma decrição das colunas tipos numéricos. essa descrição mostra valores valiosos como média, max, min, etc.
# Out:
#            Idade      Notas
# count  18.000000  12.000000
# mean   25.500000   6.800000
# std     6.070662   2.204953
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %% [markdown]
# Olha que legal! conseguimos achar a media de idades e a media de notas com o metodo describe. isso conseguimos tirar que a media de idade é 25 anos e tem uma média de 6.80.
#
# ---
#
# **sugestão: Seria interessante mais para frente descobrirmos qual idade está relacionada com as notas.**
#
# ---
#
# Agora vamos selecionar uma coluna especifica e realizar a visualização para entendermos que conseguimos trabalhar tanto individualmente, quanto em pequenos grupos.

# %%
df['Nome'] # selecionando uma coluna especifica
# Out:
# 0           Ary
# 1           Ana
# 2         Cátia
# 3         Denis
# 4          Beto
# 5         Bruna
# 6          Dara
# 7        Carlos
# 8         Alice
# 9         Vitor
# 10       Daniel
# 11         Igor
# 12    Sthefanie
# 13        Mirla
# 14        Paulo
# 15       Mylena
# 16        Lucas
# 17        Nadia
# Name: Nome, dtype: object

# %%
df[['Nome', 'Idade']] # selecionando duas colunas especificas
# Out:
#          Nome  Idade
# 0         Ary     20
# 1         Ana     18
# 2       Cátia     27
# 3       Denis     18
# 4        Beto     21
# 5       Bruna     23
# 6        Dara     21
# 7      Carlos     19
# 8       Alice     35
# 9       Vitor     28
# 10     Daniel     21
# 11       Igor     24
# 12  Sthefanie     26
# 13      Mirla     25
# 14      Paulo     37
# 15     Mylena     29
# 16      Lucas     33
# 17      Nadia     34
